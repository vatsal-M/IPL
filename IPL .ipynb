# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

Matches=pd.read_csv('E:\Pyhton codes\IPL.csv')
Matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
Matches.drop(['dl_applied','venue','umpire1','umpire2','umpire3'],axis=1,inplace=True)

# %%
Matches.reset_index(inplace=True)
Matches.head()
# Out:
#    index  id  season       city        date                        team1  \
# 0      0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2      2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result                       winner  win_by_runs  win_by_wickets  \
# ...

# %%
df=Matches.where(Matches['result']=='no result')
df.dropna(how='all',inplace=True)
a=df.index
a
# Out:
# Int64Index([300, 545, 570, 744], dtype='int64')

# %%
Matches.drop(a,inplace=True)

# %%
Matches
# Out:
#      index     id  season           city        date  \
# 0        0      1    2017      Hyderabad  2017-04-05
# 1        1      2    2017           Pune  2017-04-06
# 2        2      3    2017         Rajkot  2017-04-07
# 3        3      4    2017         Indore  2017-04-08
# 4        4      5    2017      Bangalore  2017-04-08
# 5        5      6    2017      Hyderabad  2017-04-09
# 6        6      7    2017         Mumbai  2017-04-09
# 7        7      8    2017         Indore  2017-04-10
# 8        8      9    2017           Pune  2017-04-11
# 9        9     10    2017         Mumbai  2017-04-12
# 10      10     11    2017        Kolkata  2017-04-13
# 11      11     12    2017      Bangalore  2017-04-14
# 12      12     13    2017         Rajkot  2017-04-14
# 13      13     14    2017        Kolkata  2017-04-15
# 14      14     15    2017          Delhi  2017-04-15
# 15      15     16    2017         Mumbai  2017-04-16
# 16      16     17    2017      Bangalore  2017-04-16
# ...

# %%
Matches.plot.scatter('id','win_by_runs')

# %%
df=Matches.where(Matches['id']>=7894)
df.dropna(how='all',inplace=True)
a=df.index
Matches.drop(a,inplace=True)

# %%
Matches
# Out:
#      index   id  season           city        date  \
# 0        0    1    2017      Hyderabad  2017-04-05
# 1        1    2    2017           Pune  2017-04-06
# 2        2    3    2017         Rajkot  2017-04-07
# 3        3    4    2017         Indore  2017-04-08
# 4        4    5    2017      Bangalore  2017-04-08
# 5        5    6    2017      Hyderabad  2017-04-09
# 6        6    7    2017         Mumbai  2017-04-09
# 7        7    8    2017         Indore  2017-04-10
# 8        8    9    2017           Pune  2017-04-11
# 9        9   10    2017         Mumbai  2017-04-12
# 10      10   11    2017        Kolkata  2017-04-13
# 11      11   12    2017      Bangalore  2017-04-14
# 12      12   13    2017         Rajkot  2017-04-14
# 13      13   14    2017        Kolkata  2017-04-15
# 14      14   15    2017          Delhi  2017-04-15
# 15      15   16    2017         Mumbai  2017-04-16
# 16      16   17    2017      Bangalore  2017-04-16
# ...

# %%
plt.figure(figsize=(10,15))
plt.scatter(Matches['id'],Matches['toss_winner'])

# %%
plt.figure(figsize=(10,15))
plt.scatter(Matches['id'],Matches['winner'])

# %%
plt.figure(figsize=(24,20))
ax1=plt.subplot(1,3,1)
plt.scatter(Matches['id'],Matches['toss_winner'])
ax2=plt.subplot(1,3,3,sharex=ax1,sharey=ax1)
plt.scatter(Matches['id'],Matches['winner'])

# %%
a=np.array(Matches['winner'])
plt.figure(figsize=(20,10))
plt.hist(a)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df=Matches.where(Matches['toss_winner']==Matches['winner'])
df.dropna(how='all',inplace=True)
df
# Out:
#      index     id  season           city        date  \
# 1      1.0    2.0  2017.0           Pune  2017-04-06
# 2      2.0    3.0  2017.0         Rajkot  2017-04-07
# 3      3.0    4.0  2017.0         Indore  2017-04-08
# 4      4.0    5.0  2017.0      Bangalore  2017-04-08
# 5      5.0    6.0  2017.0      Hyderabad  2017-04-09
# 6      6.0    7.0  2017.0         Mumbai  2017-04-09
# 9      9.0   10.0  2017.0         Mumbai  2017-04-12
# 10    10.0   11.0  2017.0        Kolkata  2017-04-13
# 11    11.0   12.0  2017.0      Bangalore  2017-04-14
# 12    12.0   13.0  2017.0         Rajkot  2017-04-14
# 14    14.0   15.0  2017.0          Delhi  2017-04-15
# 15    15.0   16.0  2017.0         Mumbai  2017-04-16
# 20    20.0   21.0  2017.0      Hyderabad  2017-04-19
# 21    21.0   22.0  2017.0         Indore  2017-04-20
# 22    22.0   23.0  2017.0        Kolkata  2017-04-21
# 24    24.0   25.0  2017.0           Pune  2017-04-22
# 28    28.0   29.0  2017.0           Pune  2017-04-26
# ...

# %%
plt.figure(figsize=(10,15))
plt.scatter(df['id'],df['toss_winner'],s=10)
plt.title('Matches where the toss winner won the match')
# Out:
# Text(0.5,1,'Matches where the toss winner won the match')

# %%
plt.figure(figsize=(24,20))
ax1=plt.subplot(1,3,1)
plt.scatter(Matches['id'],Matches['toss_winner'])
ax2=plt.subplot(1,3,3,sharex=ax1,sharey=ax1)
plt.scatter(Matches['id'],Matches['winner'])
ax3=plt.subplot(1,3,2,sharex=ax1,sharey=ax1)
plt.scatter(df['id'],df['toss_winner'])
plt.title('Matches where the toss winner won the match')
# Out:
# Text(0.5,1,'Matches where the toss winner won the match')

# %%
df2=Matches.where(Matches['toss_winner']!=Matches['winner'])
df2.dropna(how='all',inplace=True)
df2
# Out:
#      index     id  season           city        date  \
# 0      0.0    1.0  2017.0      Hyderabad  2017-04-05
# 7      7.0    8.0  2017.0         Indore  2017-04-10
# 8      8.0    9.0  2017.0           Pune  2017-04-11
# 13    13.0   14.0  2017.0        Kolkata  2017-04-15
# 16    16.0   17.0  2017.0      Bangalore  2017-04-16
# 17    17.0   18.0  2017.0          Delhi  2017-04-17
# 18    18.0   19.0  2017.0      Hyderabad  2017-04-17
# 19    19.0   20.0  2017.0         Rajkot  2017-04-18
# 23    23.0   24.0  2017.0         Mumbai  2017-04-22
# 25    25.0   26.0  2017.0         Rajkot  2017-04-23
# 26    26.0   27.0  2017.0        Kolkata  2017-04-23
# 27    27.0   28.0  2017.0         Mumbai  2017-04-24
# 31    31.0   32.0  2017.0     Chandigarh  2017-04-28
# 32    32.0   33.0  2017.0           Pune  2017-04-29
# 33    33.0   34.0  2017.0         Rajkot  2017-04-29
# 35    35.0   36.0  2017.0      Hyderabad  2017-04-30
# 36    36.0   37.0  2017.0         Mumbai  2017-05-01
# ...

# %%
plt.figure(figsize=(10,15))
plt.scatter(df2['id'],df2['toss_winner'],s=10)
plt.title('Matches where the toss winner didnt win the match')
# Out:
# Text(0.5,1,'Matches where the toss winner didnt win the match')

# %%
plt.figure(figsize=(30,20))
ax1=plt.subplot(1,2,1)
plt.scatter(df['id'],df['toss_winner'])
ax2=plt.subplot(1,2,2,sharex=ax1,sharey=ax1)
plt.scatter(df2['id'],df2['winner'])

# %%
plt.scatter(df['id'],df['toss_winner'],df2['id'],df2['winner'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     165     try:
# --> 166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('Sunrisers Hyderabad', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4287                 # must be acceptable as PathCollection facecolors
# -> 4288                 colors = mcolors.to_rgba_array(c)
#    4289             except ValueError:
#
# ...
